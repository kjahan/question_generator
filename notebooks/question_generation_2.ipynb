# %% [markdown]
# <a href="https://colab.research.google.com/github/kjahan/question_generator/blob/main/notebooks/question_generation_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Question generator 2
#
# We use the following model:
# https://github.com/AMontgomerie/question_generator/blob/master/examples/question_generation_example.ipynb
#
# https://huggingface.co/iarfmoose/t5-base-question-generator/blob/main/README.md

# %%
# !pip install -U transformers==3.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 754 kB 15.7 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 35.0 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 20.5 MB/s
# ...
#      |████████████████████████████████| 880 kB 12.5 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=9d66625b6cce96a6d9b40dda09a15d9541651c3afcbfcc04de417fcbe3d6d43e
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...

# %%
# !git clone https://github.com/kjahan/question_generator-1.git
# Out:
# Cloning into 'question_generator-1'...
# remote: Enumerating objects: 280, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 280 (delta 54), reused 64 (delta 48), pack-reused 188
# Receiving objects: 100% (280/280), 121.97 KiB | 6.10 MiB/s, done.
# Resolving deltas: 100% (141/141), done.

# %%
# %cd question_generator-1/
# %load questiongenerator.py
from questiongenerator import QuestionGenerator
from questiongenerator import print_qa
# Out:
# /content/question_generator/question_generator-1/question_generator-1/question_generator-1/question_generator-1/question_generator-1/question_generator-1

# %% [markdown]
# # GPU?
#
# Make sure that we're using the GPU

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
assert device == torch.device('cuda'), "Not using CUDA. Set: Runtime > Change runtime type > Hardware Accelerator: GPU"

# %% [markdown]
# Now we can create a QuestionGenerator and feed it some text. We are going to use a BBC article about Twitter getting hacked.
#
# The models should be automatically loaded when instantiating the QuestionGenerator class, but if you have them saved somewhere else you can pass the path to the folder containing them as an argument like QuestionGenerator(MODEL_DIR).

# %%
qg = QuestionGenerator()
# Out:
# Downloading:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/121 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/482 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/433M [00:00<?, ?B/s]

# %%
with open('articles/indian_matchmaking.txt', 'r') as a:
    article = a.read()

# %%
article
# Out:
# 'A new Netflix show, Indian Matchmaking, has created a huge buzz in India, but many can\'t seem to agree if it is regressive and cringe-worthy or honest and realistic, writes the BBC\'s Geeta Pandey in Delhi.\n\nThe eight-part docuseries features elite Indian matchmaker Sima Taparia as she goes about trying to find suitable matches for her wealthy clients in India and the US.\n\n"Matches are made in heaven and God has given me the job to make it successful on Earth," says Ms Taparia who claims to be "Mumbai\'s top matchmaker".\n\nIn the series, she\'s seen jet-setting around Delhi, Mumbai and several American cities, meeting prospective brides and grooms to find out what they are looking for in a life partner.\n\nSince its release nearly two weeks back, Indian Matchmaking has raced to the top of the charts for Netflix in India.\n\nIt has also become a massive social phenomenon. Hundreds of memes and jokes have been shared on social media: some say they are loving it, some say they ar
# ...

# %% [markdown]
# Now We can call QuestionGenerator's generate() method. We can choose an answer style from ['all', 'sentences', 'multiple_choice'].
#
# You can choose how many questions you want to generate by setting num_questions. Note that the quality of questions may decrease if num_questions is high.
#
# If you just want to print the questions without showing the answers, you can optionally set show_answers=False when calling print_qa().

# %%
qa_list = qg.generate(
    article, 
    num_questions=10, 
    answer_style='all'
)
print_qa(qa_list)
# Out:
# Generating questions...
#
# Evaluating QA pairs...
#
# 1) Q: What would have been offended if Sima Aunty spoke about?
#    A: In fact, I would have been offended if Sima Aunty was woke and spoke about choice, body positivity and clean energy during matchmaking.
#
# 2) Q: What does she think of Indian Matchmaking?
#    A: " Ms Vetticad describes Indian Matchmaking as "occasionally insightful" and says "parts of it are hilarious because Ms Taparia's clients are such characters and she herself is so unaware of her own regressive mindset".
#
# 3) Q: What do parents do to find a suitable match?
#    A: Parents also trawl through matrimonial columns in newspapers to find a suitable match for their children.
#
# 4) Q: In what country does Sima taparia try to find suitable matches for her wealthy clients?
#    A: 1. Delhi
#       2. Netflix
#       3. US (correct)
#       4. India
#
# 5) Q: What is the reason why she is being called out?
# ...

# %%
with open('articles/atoms.txt', 'r') as a:
    atom_article = a.read()

qa_list = qg.generate(
    atom_article, 
    num_questions=10, 
    answer_style='all'
)
print_qa(qa_list)
# Out:
# Generating questions...
#
# Evaluating QA pairs...
#
# 1) Q: does a neutral sodium atom react with water more violently than an ionized?
#    A: For instance, a neutral sodium atom (say, from a chunk of sodium metal) reacts with water much more violently than an ionized sodium atom (say, from a bit of salt).
#
# 2) Q: does an atom come with an equal number of protons and electrons?
#    A: Even if left alone, an atom often does not come with an equal number of protons and electrons.
#
# 3) Q: is it enough to say what atoms are involved in a reaction?
#    A: It's not enough to say what atoms are involved if you want to fully describe and predict a reaction.
#
# 4) Q: can two atoms of the same chemical element react differently?
#    A: Since the states of the electrons in an atom are what determine the nature of the chemical bonding that the atom experiences, two atoms of the same element can react differently if they are in different states.
#
# ...

# %%
with open('articles/methylprednisolone.txt', 'r') as a:
    methyl_article = a.read()

qa_list = qg.generate(
    methyl_article, 
    num_questions=10, 
    answer_style='all'
)
print_qa(qa_list)
# Out:
# Generating questions...
#
# Evaluating QA pairs...
#
# 1) Q: what is methylprednisolone used for?
#    A: Methylprednisolone is used to treat conditions such as arthritis, blood disorders, severe allergic reactions, certain cancers, eye conditions, skin/kidney/intestinal/lung diseases, and immune system disorders.
#
# 2) Q: what is methylprednisolone used for?
#    A: Methylprednisolone may also be used with other medications in hormone disorders.
#
# 3) Q: what is the dosage of methylprednisolone?
#    A: The dosage and length of treatment are based on your medical condition and response to treatment.
#
# 4) Q: what is methylprednisolone?
#    A: This medication is a corticosteroid hormone.
#
# 5) Q: what is methylprednisolone used for?
#    A: It decreases your immune system's response to various diseases to reduce symptoms such as swelling, pain, and allergic-type reactions.
#
# 6) Q: what do you take with methylprednisolone?
# ...

# %%
with open('articles/azithromycin.txt', 'r') as a:
    azithromycin_article = a.read()

qa_list = qg.generate(
    azithromycin_article, 
    num_questions=10, 
    answer_style='all'
)
print_qa(qa_list)
# Out:
# Generating questions...
#
# Evaluating QA pairs...
#
# 1) Q: What is the best way to take azithromycin?
#    A: Read the Patient Information Leaflet if available from your pharmacist before you start taking azithromycin and each time you get a refill.
#
# 2) Q: What is the best way to stop the bacteria from growing?
#    A: Stopping the medication too early may allow bacteria to continue to grow, which may result in a return of the infection.
#
# 3) Q: what can lead to the decreased effectiveness of azithromycin?
#    A: Unnecessary use or misuse of any antibiotic can lead to its decreased effectiveness.
#
# 4) Q: what is azithromycin used for?
#    A: Azithromycin is used to treat a wide variety of bacterial infections.
#
# 5) Q: How often should you take azithromycin?
#    A: Take this medication by mouth as directed by your doctor, usually once daily with or without food.
#
# 6) Q: What is the dosage of azithromycin?
# ...

# %%
with open('articles/ivermectin.txt', 'r') as a:
    ivermectin_article = a.read()

qa_list = qg.generate(
    ivermectin_article, 
    num_questions=10, 
    answer_style='all'
)
print_qa(qa_list)
# Out:
# Generating questions...
#
# Evaluating QA pairs...
#
# 1) Q: what is ivermectin used for?
#    A: Ivermectin is used to treat certain parasitic roundworm infections.
#
# 2) Q: what is ivermectin?
#    A: Ivermectin belongs to a class of drugs known as antihelmintics.
#
# 3) Q: isvermectin recommended for cvs?
#    A: Ivermectin is not recommended for coronavirus disease, also known as COVID-19, unless you are enrolled in a study.
#
# 4) Q: what is not recommended for coronavirus disease?
#    A: 1. 8 ounces
#       2. 240 milliliters
#       3. Dosage
#       4. Ivermectin (correct)
#
# 5) Q: what is ivermectin?
#    A: Ivermectin is usually taken as a single dose or series of doses, or as directed by your doctor.
#
# 6) Q: how long before taking this medication?
#    A: 1. at least 1 hour (correct)
#       2. Ivermectin
#       3. 8 ounces
#       4. 240 milliliters
#
# 7) Q: What is the best way to treat roundworm infections?
# ...

# %%
with open('articles/ERC721A.txt', 'r') as a:
    article = a.read()

qa_list = qg.generate(
    article, 
    num_questions=3, 
    answer_style='all'
)
print_qa(qa_list)
# Out:
# Generating questions...
#
# Evaluating QA pairs...
#
# 1) Q: how many tokens were minted in minutes?
#    A: There was significant demand for 8700 tokens made available to the public, and all were minted within minutes.
#
# 2) Q: What is the goal of ERC721A?
#    A: The goal of ERC721A is to provide a fully compliant implementation of IERC721 with significant gas savings for minting multiple NFTs in a single transaction.
#
# 3) Q: what is the goal of erc721a?
#    A: This project and implementation will be updated regularly and will continue to stay up to date with best practices.

# %%
with open('articles/copilot.txt', 'r') as a:
    article = a.read()

qa_list = qg.generate(
    article, 
    num_questions=5, 
    answer_style='all'
)
print_qa(qa_list)
# Out:
# Generating questions...
#
# Evaluating QA pairs...
#
# 1) Q: What is the name of the software that was unveiled by GitHub in June 2021?
#    A: Copilot, which was unveiled by Microsoft-owned GitHub in June 2021, is trained on public repositories of code scraped from the web, many of which are published with licenses that require anyone reusing the code to credit its creators.
#
# 2) Q: Who is letting other’s code without attribution kill the open source movement?
#    A: 1. GitHub Copilot
#       2. OpenAI
#       3. AI
#       4. Microsoft (correct)
#
# 3) Q: Did Microsoft respond to similar requests at the time of publication?
#    A: ” OpenAI and Microsoft had not replied to similar requests at the time of publication.
#
# 4) Q: Who filed the lawsuit?
#    A: “We are challenging the legality of GitHub Copilot,” said programmer and lawyer Matthew Butterick, who filed the lawsuit with the help of the San Francisco-based Joseph Saveri Law Firm, in a press statement.
#
# ...
