# %% [markdown]
# <a href="https://colab.research.google.com/github/kjahan/question_generator/blob/main/notebooks/question_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Question generation
#
# Trying different models for generating questions.
#
# Use case: publishoing questions and generating traffics.
#
# Ref:
# https://github.com/patil-suraj/question_generation

# %%
# !pip install -U transformers==3.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 754 kB 17.6 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 40.5 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 49.1 MB/s
# ...
#      |████████████████████████████████| 880 kB 49.6 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=082210ae24f9488b8d71a29b6ab925083330bd81d07770356841ceb7fca06acc
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...

# %%
# !python -m nltk.downloader punkt
# Out:
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !git clone https://github.com/patil-suraj/question_generation.git
# Out:
# Cloning into 'question_generation'...
# remote: Enumerating objects: 268, done.
# remote: Total 268 (delta 0), reused 0 (delta 0), pack-reused 268
# Receiving objects: 100% (268/268), 299.04 KiB | 1.41 MiB/s, done.
# Resolving deltas: 100% (140/140), done.

# %%
text1 = "Python is an interpreted, high-level, general-purpose programming language. Created by Guido van Rossum \
and first released in 1991, Python's design philosophy emphasizes code \
readability with its notable use of significant whitespace."

text2 = "Gravity (from Latin gravitas, meaning 'weight'), or gravitation, is a natural phenomenon by which all \
things with mass or energy—including planets, stars, galaxies, and even light—are brought toward (or gravitate toward) \
one another. On Earth, gravity gives weight to physical objects, and the Moon's gravity causes the ocean tides. \
The gravitational attraction of the original gaseous matter present in the Universe caused it to begin coalescing \
and forming stars and caused the stars to group together into galaxies, so gravity is responsible for many of \
the large-scale structures in the Universe. Gravity has an infinite range, although its effects become increasingly \
weaker as objects get further away"

text3 = "42 is the answer to life, universe and everything."

text4 = "Forrest Gump is a 1994 American comedy-drama film directed by Robert Zemeckis and written by Eric Roth. \
It is based on the 1986 novel of the same name by Winston Groom and stars Tom Hanks, Robin Wright, Gary Sinise, \
Mykelti Williamson and Sally Field. The story depicts several decades in the life of Forrest Gump (Hanks), \
a slow-witted but kind-hearted man from Alabama who witnesses and unwittingly influences several defining \
historical events in the 20th century United States. The film differs substantially from the novel."

# %% [markdown]
# ## Single task QA

# %%
# %cd question_generation
# Out:
# /content/question_generation

# %%
from pipelines import pipeline

# %%
qg_model_1 = pipeline("question-generation")

# %%
qg_model_1(text3)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# [{'answer': '42',
#   'question': 'What is the answer to life, universe and everything?'}]

# %% [markdown]
# If you want to use the t5-base model, then pass the path through model parameter

# %%
qg_model_2 = pipeline("question-generation", model="valhalla/t5-base-qg-hl")

# %%
qg_model_2(text3)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# [{'answer': '42',
#   'question': 'What is the answer to life, universe and everything?'}]

# %%
qg_model_2(text4)
# Out:
# [{'answer': 'Robert Zemeckis', 'question': 'Who directed Forrest Gump?'},
#  {'answer': 'Eric Roth', 'question': 'Who wrote Forrest Gump?'},
#  {'answer': '1986',
#   'question': "In what year was Winston Groom's novel published?"},
#  {'answer': 'Alabama', 'question': 'Where is Forrest Gump from?'},
#  {'answer': 'differs substantially from the novel',
#   'question': 'How does Forrest Gump compare to the novel?'}]

# %%
qg_model_2(text2)
# Out:
# [{'answer': 'gravitation', 'question': 'What is another name for gravity?'},
#  {'answer': 'Earth',
#   'question': 'On what planet does gravity give weight to physical objects?'},
#  {'answer': 'galaxies', 'question': 'What do the stars in the Universe form?'},
#  {'answer': 'infinite range', 'question': 'What is the range of gravity?'}]

# %% [markdown]
# ## Multitask QA-QG

# %% [markdown]
# ### small-model

# %%
qg_model_3 = pipeline("multitask-qa-qg")

# %% [markdown]
# #### QG

# %%
qg_model_3(text1)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# [{'answer': 'Python',
#   'question': 'What is an interpreted, high-level, general-purpose programming language?'},
#  {'answer': 'Guido van Rossum', 'question': 'Who created Python?'}]

# %%
qg_model_3(text2)
# Out:
# [{'answer': 'gravitation',
#   'question': 'What is a natural phenomenon called when all things with mass or energy are brought toward one another?'},
#  {'answer': 'Earth',
#   'question': 'On what planet does gravity give weight to physical objects?'},
#  {'answer': 'galaxies', 'question': 'What did the stars group together into?'},
#  {'answer': 'infinite range',
#   'question': 'What kind of range does Gravity have?'}]

# %%
qg_model_3(text4)
# Out:
# [{'answer': 'Robert Zemeckis', 'question': 'Who directed Forrest Gump?'},
#  {'answer': 'Eric Roth', 'question': 'Who wrote Forrest Gump?'},
#  {'answer': '1986', 'question': 'In what year was Forrest Gump based?'},
#  {'answer': 'Alabama', 'question': 'Where is Forrest Gump from?'},
#  {'answer': 'differs substantially from the novel',
#   'question': 'What does Forrest Gump differ from the novel?'}]

# %% [markdown]
# #### QA

# %%
qg_model_3({
  "question": "Who created Python ?",
  "context": text1
})
# Out:
# 'Guido van Rossum'

# %%
qg_model_3({
    "question": "Who wrote Forrest Gump ?",
     "context": text4
})
# Out:
# 'Eric Roth'

# %% [markdown]
# ### base-model

# %%
qg_model_4 = pipeline("multitask-qa-qg", model="valhalla/t5-base-qa-qg-hl")
# Out:
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %% [markdown]
# #### QG

# %%
qg_model_4(text1)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# [{'answer': 'Python',
#   'question': 'What programming language was created by Guido van Rossum?'},
#  {'answer': 'Guido van Rossum', 'question': 'Who created Python?'},
#  {'answer': '1991', 'question': 'When was Python first released?'}]

# %%
qg_model_4(text2)
# Out:
# [{'answer': 'gravitation', 'question': 'What is another name for gravity?'},
#  {'answer': 'Earth',
#   'question': 'On what planet does gravity give weight to physical objects?'},
#  {'answer': 'galaxies', 'question': 'What do the stars form into?'},
#  {'answer': 'weaker',
#   'question': "Gravity's effects become what as objects get further away?"}]

# %%
qg_model_4(text4)
# Out:
# [{'answer': '1994', 'question': 'When was Forrest Gump released?'},
#  {'answer': '1986',
#   'question': "In what year was Winston Groom's novel based on Forrest Gump?"},
#  {'answer': 'Alabama', 'question': 'Where is Forrest Gump from?'},
#  {'answer': 'novel',
#   'question': 'Forrest Gump differs substantially from what?'}]

# %% [markdown]
# #### QA

# %%
qg_model_4({
  "question": "Who created Python ?",
  "context": text1
})
# Out:
# 'Guido van Rossum'

# %%
qg_model_4({
    "question": "Who wrote Forrest Gump ?",
     "context": text4
})
# Out:
# 'Eric Roth'

# %% [markdown]
# ## End-to-End QG

# %% [markdown]
# ### small model

# %%
qg_model_5 = pipeline("e2e-qg")
# Out:
# Downloading:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]

# %%
qg_model_5(text1)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# ['Who created Python?',
#  'When was Python first released?',
#  "What is Python's design philosophy?"]

# %%
qg_model_5(text2)
# Out:
# ['What is the Latin word for gravitas?',
#  'What does gravity give weight to on Earth?',
#  "The Moon's gravity causes what?",
#  'Gravity has an infinite range, but its effects become weaker as objects get further away?']

# %%
qg_model_5(text4)
# Out:
# ['Who directed the 1994 American comedy-drama film Forrest Gump?',
#  'What is the name of the 1986 film that stars Tom Hanks, Robin Wright, Gary Sinise, Mykelti Williamson, and Sally Field?',
#  'Who is the author of the 1994 film forrest gump? What is Forrest a film that is based on?']

# %% [markdown]
# ### base-model

# %%
qg_model_6 = pipeline("e2e-qg", model="valhalla/t5-base-e2e-qg")
# Out:
# Downloading:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/195 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
qg_model_6(text1)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# ['Who created Python?',
#  'When was Python first released?',
#  "What is Python's design philosophy?"]

# %%
qg_model_6(text2)
# Out:
# ['What is the Latin word for gravitation?',
#  'What does gravity give to physical objects on Earth?',
#  "The Moon's gravity causes what?",
#  'Gravity has an infinite range, but its effects become weaker as objects get further away?']

# %%
qg_model_6(text4)
# Out:
# ['Who directed Forrest Gump?',
#  'Who wrote the book of the same name?',
#  "What is the name of the film based on Winston Groom's novel?",
#  'Which actor stars in the film?']

# %% [markdown]
# ## New Sets of questions
#
# https://www.wtamu.edu/~cbaird/sq/2014/11/12/do-poppy-seeds-contain-narcotics/

# %%
text5 = "Poppy seeds contain narcotics. Poppy seeds are used to add flavor to many baked goods, salads, and pasta dishes; ranging from lemon bread to chicken salad."

text6 = "It is scientifically possible to turn your beloved deceased pet or human relative into a diamond that you wear on your finger as a token of remembrance."

text7 = "Diamond can be burned. The most common form of burning in everyday life is carbon combustion. In carbon combustion, carbon atoms break their bonds with each other and with other atoms."

text8 = "Two atoms of the same chemical element are typically not identical. First of all, there is a range of possible states that the electrons of an atom can occupy. Two atoms of the same element can be different if their electrons are in different states."

text9 = "Donald John Trump (born June 14, 1946) is an American politician, media personality, and businessman who served as the 45th president of the United States from 2017 to 2021.molecular masscarbon dioxide"

# %%
qg_model_1(text7)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# [{'answer': 'Diamond', 'question': 'What can be burned?'},
#  {'answer': 'carbon combustion',
#   'question': 'What is the most common form of burning in everyday life?'},
#  {'answer': 'carbon atoms',
#   'question': 'What break bonds with each other and with other atoms in carbon combustion?'}]

# %%
qg_model_2(text7)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# [{'answer': 'Diamond', 'question': 'What metal can be burned?'},
#  {'answer': 'carbon combustion',
#   'question': 'What is the most common form of burning diamonds?'},
#  {'answer': 'carbon atoms',
#   'question': 'What breaks their bonds with each other and with other atoms in carbon combustion?'}]

# %%
qg_model_3(text7)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# [{'answer': 'Diamond', 'question': 'What can be burned?'},
#  {'answer': 'carbon combustion',
#   'question': 'What is the most common form of burning in everyday life?'},
#  {'answer': 'carbon atoms',
#   'question': 'What break bonds with each other and with other atoms in carbon combustion?'}]

# %%
qg_model_3({
  "question": "Can you light diamond on fire?",
  "context": text7
})
# Out:
# 'can be burned'

# %%
qg_model_4(text7)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# [{'answer': 'Diamond', 'question': 'What can be burned?'},
#  {'answer': 'carbon combustion',
#   'question': 'What is the most common form of burning diamonds?'},
#  {'answer': 'carbon combustion',
#   'question': 'What is the process in which carbon atoms break their bonds with each other?'}]

# %%
qg_model_4({
  "question": "Can you light diamond on fire?",
  "context": text7
})
# Out:
# 'can be burned'

# %%
qg_model_5(text7)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# ['What can be burned?',
#  'What is the most common form of burning in everyday life?',
#  'How do carbon atoms break their bonds with each other?']

# %%
qg_model_6(text7)
# Out:
# ['What is the most common form of burning in everyday life?',
#  'What breaks their bonds with each other in carbon combustion?']

# %%
qg_model_1(text5)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# [{'answer': 'narcotics', 'question': 'What does Poppy seeds contain?'},
#  {'answer': 'chicken',
#   'question': 'What type of salad is used to add flavor to baked goods?'}]

# %%
qg_model_6(text5)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# ['What do poppy seeds contain?',
#  'What is used to add flavor to baked goods, salads, and pasta dishes?']

# %%
qg_model_4({
  "question": "Do poppy seeds contain narcotics?",
  "context": text5
})
# Out:
# 'contain narcotics'

# %% [markdown]
# ## New questions
#
# https://www.wtamu.edu/~cbaird/sq/2013/06/07/how-can-the-heart-be-strong-enough-to-pump-blood-up-your-legs-against-gravity/

# %%
text10 = "The heart is not strong enough by itself to get the blood back up the veins in your legs and back to your heart. The human body relies on a second system to finish that task. This system involves small valves throughout the veins and muscle contractions from your skeletal muscles when you walk and move about. The valves close when blood starts to flow in one direction, so that blood in the veins can only flow in the direction back to the heart, which is up the legs. When you squeeze your leg muscles to walk, stand, kick, and move about, the muscles squeeze the veins and force the blood to get moving. Because of the valves, the blood can only move in one direction as it gets squeezed along. So it is a combination of blood pressure from the heart's pumping action, the valves, and muscle movement that gets the blood up the legs against gravity. If the valves malfunction, then the blood falls back down to some extent after every muscle contraction and begins to pool in the veins. This causes the veins to swell with blood, which can be painful and unsightly, and is known as varicose veins."

# %%
qg_model_3(text10)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1500: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# [{'answer': 'The heart',
#   'question': 'What is not strong enough to get the blood back up the veins in your legs and back to your heart?'},
#  {'answer': 'second system',
#   'question': 'What system does the human body use to complete the process of getting blood back up the veins in your legs and back to your heart?'},
#  {'answer': 'small valves',
#   'question': 'What does the second system involve throughout the veins and muscle contractions from your skeletal muscles when you walk?'},
# ...

# %%
qg_model_3({
  "question": "How can the heart be strong enough to pump blood up your legs against gravity?",
  "context": text10
})
# Out:
# "a combination of blood pressure from the heart's pumping action,"
